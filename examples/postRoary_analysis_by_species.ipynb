# %% [markdown]
# # Roary Results for all Genomes with a BLASTp = 90%

# %% [markdown]
# ## Capsule

# %%
from src.PostRoaryPlotter import GenePresenceAbsencePlotter, GenePresenceAbsenceCluster, GenePresenceAbsencePivot

data_path = '/Volumes/Crucial_X9/BioFago/data/ALLApproachFlankGenes/capsule/roary/roary_90_1710760472/gene_presence_absence.csv'

plotter = GenePresenceAbsencePlotter(data_path)
plotter.load_and_process_data()
plotter.process_strain_names()  # Simplify the strain names for JSON search
plotter.identify_unique_patterns()
plotter.plot_heatmap()

# %% [markdown]
# Make the refined csv with the species defined for each strain

# %%
json_path = '/Volumes/Crucial_X9/BioFago/data/genomesAllErwinia/ncbi_dataset/ncbi_dataset/data/assembly_data_report.jsonl'
output_to_save_csv = '/Users/josediogomoura/Documents/BioFago/BioFago/data/recent_outputs/PostRoary/AllGenomes/capsule/presence_absence.csv'
plotter.make_final_csv(output_to_save_csv, json_path)
# Out:
# 2024-03-19 14:38:41,307 - INFO - CSV file saved to /Users/josediogomoura/Documents/BioFago/BioFago/data/recent_outputs/PostRoary/AllGenomes/capsule/presence_absence.csv

# %% [markdown]
# ## Pivot table visualisation

# %%
refined_csv = "/Users/josediogomoura/Documents/BioFago/BioFago/data/recent_outputs/PostRoary/AllGenomes/capsule/presence_absence.csv"
pivot = GenePresenceAbsencePivot(data_path=refined_csv)
pivot.process_and_plot()

# %% [markdown]
# ## Clustered heatmap

# %%
cluster = GenePresenceAbsenceCluster(data_path=refined_csv)
cluster.process_and_plot()

# %% [markdown]
# ## Cellulose

# %%
data_path = "/Volumes/Crucial_X9/BioFago/data/ALLApproachFlankGenes/cellulose/roary/roary_90_1710761582/gene_presence_absence.csv"
plotter = GenePresenceAbsencePlotter(data_path)
plotter.load_and_process_data()
plotter.process_strain_names()
plotter.identify_unique_patterns()
plotter.plot_heatmap()

# %% [markdown]
# Make the refined csv with the species defined for each strain

# %%
json_path = '/Volumes/Crucial_X9/BioFago/data/genomesAllErwinia/ncbi_dataset/ncbi_dataset/data/assembly_data_report.jsonl'
output_to_save_csv = '/Users/josediogomoura/Documents/BioFago/BioFago/data/recent_outputs/PostRoary/AllGenomes/cellulose/presence_absence.csv'
plotter.make_final_csv(output_to_save_csv, json_path)
# Out:
# 2024-03-19 14:34:10,097 - INFO - CSV file saved to /Users/josediogomoura/Documents/BioFago/BioFago/data/recent_outputs/PostRoary/AllGenomes/cellulose/presence_absence.csv

# %% [markdown]
# ## Pivot table visualisation

# %%
refined_csv = "/Users/josediogomoura/Documents/BioFago/BioFago/data/recent_outputs/PostRoary/AllGenomes/cellulose/presence_absence.csv"
pivot = GenePresenceAbsencePivot(data_path=refined_csv)
pivot.process_and_plot()

# %%
cluster = GenePresenceAbsenceCluster(data_path=refined_csv)
cluster.process_and_plot()

# %% [markdown]
# ## LPS

# %%
data_path = "/Volumes/Crucial_X9/BioFago/data/ALLApproachFlankGenes/lps/roary/roary_90_1710770806/gene_presence_absence.csv"
plotter = GenePresenceAbsencePlotter(data_path)
plotter.load_and_process_data()
plotter.process_strain_names()
plotter.identify_unique_patterns()
plotter.plot_heatmap()

# %% [markdown]
# Make the refined csv with the species defined for each strain

# %%
json_path = '/Volumes/Crucial_X9/BioFago/data/genomesAllErwinia/ncbi_dataset/ncbi_dataset/data/assembly_data_report.jsonl'
output_to_save_csv = '/Users/josediogomoura/Documents/BioFago/BioFago/data/recent_outputs/PostRoary/AllGenomes/lps/presence_absence.csv'
plotter.make_final_csv(output_to_save_csv, json_path)
# Out:
# 2024-03-19 14:36:30,631 - INFO - CSV file saved to /Users/josediogomoura/Documents/BioFago/BioFago/data/recent_outputs/PostRoary/AllGenomes/lps/presence_absence.csv

# %%
refined_csv = "/Users/josediogomoura/Documents/BioFago/BioFago/data/recent_outputs/PostRoary/AllGenomes/lps/presence_absence.csv"
pivot = GenePresenceAbsencePivot(data_path=refined_csv)
pivot.process_and_plot()

# %%
cluster = GenePresenceAbsenceCluster(data_path=refined_csv)
cluster.process_and_plot()
